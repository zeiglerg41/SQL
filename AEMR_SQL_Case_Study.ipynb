# %% [markdown]
# <center><h1 style="color:#D4AF37"> ⚡⚡ AEMR Data Analysis ⚡⚡</h1>

# %% [markdown]
# <img src = "https://images.squarespace-cdn.com/content/v1/551972d8e4b0d571edc2e2c8/8f3abd33-0916-4415-9b24-593eea1d1e3c/Screen+Shot+2022-04-20+at+12.41.24+PM.png">
#
#
# Imagine you are an analyst for American Energy Market Regulator (AEMR).
#
# The analytics team has supplied you with the following table extract that contains all the data you need to analyse for the `AEMR` outages.
#
# <li> AEMR_Outage_Table </li>
#
# Let's outline the problem below and understand what we're seeking to solve.

# %% [markdown]
# <h1 style="color:#D4AF37"> What's the Business Problem? 💰</h1>
#
# The American Energy Market Regulator (AEMR) is responsible for looking after the
# United States of America’s domestic energy network. The regulator’s responsibility is to
# ensure that America’s energy network remains reliable with minimal disruptions, which
# are known as outages.
#
# There are four key types of outages:
#
# ● Consequential
#
# ● Forced
#
# ● Opportunistic
#
# ● Planned
#
# Recently, the AEMR management team has been increasingly aware of a large number
# of energy providers that submitted outages over the 2016 and 2017 calendar years. The
# management team has expressed a desire to have the following two areas of concern
# addressed:
#
# <b> A) Energy Stability and Market Outages
#     <p>
# B) Energy Losses and Market Reliability </b>
#
# As an analyst within the data and reporting team, you have been asked to address these
# two immediate areas of concern. Feel free to also explore beyond the queries asked and provide additional insights that you feel may be of interest to the management team.

# %% [markdown]
# To load the `AEMR.db` file into this notebook, run the below cells.
#
# <b> ⚠️ Please remember that everytime you close this file and re-open this, you'll need to re-run the cells below. ⚠️ </b>

# %%
# %%capture
# !pip install ipython-sql sqlalchemy
import sqlalchemy
sqlalchemy.create_engine("sqlite:///AEMR.db")
# %load_ext sql
# %sql sqlite:///AEMR.db

# %%
# %%js
# require(['notebook/js/codecell'], function (codecell) {
#     codecell.CodeCell.options_default.highlight_modes['magic_text/x-mssql'] = { 'reg': [/%?%sql/] };
#     Jupyter.notebook.events.one('kernel_ready.Kernel', function () {
#         Jupyter.notebook.get_cells().map(function (cell) {
#             if (cell.cell_type == 'code') { cell.auto_highlight(); }
#         });
#     });
# });

# %% [markdown]
# <h3 style="color:#D4AF37"> ⚡ Part I. Energy Stability & Market Outages ⚡ </h3>
#
# Energy stability is one of the key themes the AEMR management team cares about. To ensure energy security and reliability, AEMR needs to understand the following:
# <p>
# <b>
#
# <li> What are the most common outage types and how long do they tend to last?
# <li> How frequently do the outages occur?
# <li> Are there any energy providers which have more outages than their peers which may be indicative of being unreliable?
#
# <p>
#
# <u style="color:Maroon"> Please note that throughout the entire case study, we are interested ONLY in the Outages where Status = Approved. We don't have any interest in Outages that were cancelled or not approved. This means your WHERE Clause will ALWAYS contain the field `Where Status = Approved` </u>

# %% [markdown]
# <h3 style="color:#D4AF37"> Question One </h3>
#
# <b> Write a SQL Statement to `COUNT` the number of valid (i.e. `Status = Approved`) Outage Events sorted by their respective `Outage_Reason` (i.e. `Forced`, `Consequential`, `Scheduled`, `Opportunistic`) over the 2016 & 2017 Periods. </b>
#
# Do we notice anything regarding the trends for specific Outages over the 2016 / 2017 Period?

# %%
# %%sql
# SELECT *
# FROM AEMR_Outage_Table
# LIMIT 5;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(1, '2017-12-28 06:00', '2017-12-28 10:00', 2017, 12, 'DNHR_DENMARK_WF1', 'DNHR', 'Approved', 'Consequential', 1.44, 'a network outage in Denmark caused the windfarm to trip at 6:26 am'),
#  (2, '2017-12-26 09:00', '2017-12-27 00:00', 2017, 12, 'COLLGAR_WF1', 'COLLGAR', 'Approved', 'Forced', 30.0, 'Forced Outage - BS on Overhead line pole S-81 - CG10/11'),
#  (3, '2017-12-31 09:00', '2017-12-31 09:00', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 5.702999999999999, 'Under generation - ambient conditions'),
#  (4, '2017-12-31 08:30', '2017-12-31 08:30', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 5.085, 'Under generation - ambient conditions'),
#  (5, '2017-12-31 08:00', '2017-12-31 08:00', 2017, 12, 'AURICON_PNJ_U1', 'AURICON', 'Approved', 'Forced', 5.02, 'Under generation - ambient conditions')]

# %%
# %%sql
# SELECT Year, Outage_Reason, count(*) Total_Number_Outages
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Outage_Reason, Year;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 'Consequential', 181),
#  (2017, 'Consequential', 127),
#  (2016, 'Forced', 1264),
#  (2017, 'Forced', 1622),
#  (2016, 'Opportunistic Maintenance (Planned)', 106),
#  (2017, 'Opportunistic Maintenance (Planned)', 102),
#  (2016, 'Scheduled (Planned)', 380),
#  (2017, 'Scheduled (Planned)', 320)]

# %% [markdown]
# Now how about examining some monthly trends? Do we note any behaviours across the months that indicate certain months having more reliability issues over other months?

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Two </h3>

# %% [markdown]
# <b> i) Write a SQL Statement showing the `Total` of all Outage Types (Forced, Consequential, Scheduled, Opportunistic) that are valid outages, that occurred for both 2016 and 2017, grouped by `Year` and `Month`.  per month (i.e. 1 – 12). Order by `Year`, `Month`, `Total_Number_Outages` in Descending Order.
#
#
# ii) Can we identify whether there is any outage type specifically increasing on a monthly basis when comparing 2016 to 2017. </b>

# %%
# %%sql
# SELECT Year, Month, count(*) as Total_Number_Outages
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Year, Month
# ORDER BY Year, Month, Total_Number_Outages DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 1, 191),
#  (2016, 2, 227),
#  (2016, 3, 136),
#  (2016, 4, 134),
#  (2016, 5, 174),
#  (2016, 6, 168),
#  (2016, 7, 147),
#  (2016, 8, 194),
#  (2016, 9, 124),
#  (2016, 10, 124),
#  (2016, 11, 200),
#  (2016, 12, 112),
#  (2017, 1, 103),
#  (2017, 2, 150),
#  (2017, 3, 109),
#  (2017, 4, 127),
#  (2017, 5, 166),
#  (2017, 6, 204),
#  (2017, 7, 210),
#  (2017, 8, 209),
#  (2017, 9, 172),
#  (2017, 10, 276),
#  (2017, 11, 197),
#  (2017, 12, 248)]

# %% [markdown]
# Hmm. Interesting. We've now identified that <b> `Forced` </b> outage type is rapidly increasing from 2016 to 2017. However, frequency is just one aspect we care about. We also care about the <b> `duration` </b> of our ouatges.
#
# In other words, if an outage is very short, we aren't as concerned. However, if the outage is very long, this then has the risk of threatening our energy supplies. We want to identify the problematic energy providers here. This leads us to our next question below.

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Three </h3>

# %% [markdown]
# <b>Write a SQL statement that calculates 1) The `Total_Number_Outage_Events` and 2) The <b> `Average Duration`</b> in <u>DAYS</u> for each `Participant Code` and `Outage Type` over the 2016 and 2017 Period where the `Status = Approved`.
# Order by `Total_Number_Outage_Events` in Descending Order, `Reason` and `Year`. </b>

# %%
# %%sql
# SELECT Year, Outage_Reason, Participant_Code, count(*) Total_Number_Outages,
# ROUND(AVG(ABS(JULIANDAY(Start_Time) - JULIANDAY(End_Time))),2) as Average_Outage_Duration_In_Days
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Year, Outage_Reason, Participant_Code
# ORDER BY Total_Number_Outages DESC, Outage_Reason, Year;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2017, 'Forced', 'AURICON', 490, 0.07),
#  (2016, 'Forced', 'GW', 317, 0.38),
#  (2017, 'Forced', 'GW', 227, 1.06),
#  (2016, 'Forced', 'AURICON', 208, 0.07),
#  (2016, 'Forced', 'AUXC', 206, 0.08),
#  (2017, 'Forced', 'MELK', 177, 2.28),
#  (2017, 'Forced', 'TRMOS', 172, 0.42),
#  (2016, 'Forced', 'MELK', 157, 0.83),
#  (2017, 'Forced', 'PUG', 135, 0.25),
#  (2017, 'Forced', 'AUXC', 120, 0.02),
#  (2016, 'Scheduled (Planned)', 'MELK', 85, 4.61),
#  (2016, 'Forced', 'PJRH', 81, 1.22),
#  (2017, 'Forced', 'KORL', 76, 1.21),
#  (2017, 'Forced', 'PJRH', 72, 0.84),
#  (2017, 'Scheduled (Planned)', 'MELK', 70, 6.89),
#  (2016, 'Forced', 'PMC', 69, 0.49),
#  (2016, 'Forced', 'TRMOS', 65, 0.19),
#  (2016, 'Forced', 'KORL', 53, 0.38),
#  (2016, 'Scheduled (Planned)', 'AURICON', 46, 1.89),
#  (2017, 'Forced', 'COLLGAR', 45, 1.38),
#  (2016, 'Scheduled (Planned)', 'GW', 45, 4.43),
#  (2017, 'Scheduled (Planned)', 'AURICON', 45, 1.45),
#  (2017, 'Consequential', 'AURICON', 42, 0.21),
#  (2016, 'Consequential', 'AURICON', 41, 0.13),
#  (2017, 'Forced', 'PMC', 40, 0.04),
#  (2017, 'Opportunistic Maintenance (Planned)', 'PJRH', 39, 0.24),
#  (2016, 'Scheduled (Planned)', 'PJRH', 38, 2.37),
#  (2017, 'Scheduled (Planned)', 'ENRG', 37, 4.96),
#  (2017, 'Scheduled (Planned)', 'PJRH', 35, 2.61),
#  (2016, 'Consequential', 'TSLA_MGT', 30, 0.44),
#  (2016, 'Forced', 'COLLGAR', 29, 1.11),
#  (2016, 'Scheduled (Planned)', 'ENRG', 29, 4.85),
#  (2017, 'Scheduled (Planned)', 'TSLA_MGT', 28, 0.99),
#  (2016, 'Scheduled (Planned)', 'PMC', 27, 1.9),
#  (2017, 'Scheduled (Planned)', 'GW', 26, 2.65),
#  (2016, 'Forced', 'PUG', 24, 0.92),
#  (2016, 'Opportunistic Maintenance (Planned)', 'MELK', 24, 0.71),
#  (2017, 'Consequential', 'TSLA_MGT', 23, 0.34),
#  (2016, 'Opportunistic Maintenance (Planned)', 'PJRH', 23, 0.18),
#  (2016, 'Scheduled (Planned)', 'TSLA_MGT', 23, 1.97),
#  (2016, 'Forced', 'ENRG', 21, 2.24),
#  (2016, 'Consequential', 'GW', 20, 0.18),
#  (2016, 'Opportunistic Maintenance (Planned)', 'GW', 20, 0.31),
#  (2016, 'Scheduled (Planned)', 'KORL', 20, 6.96),
#  (2017, 'Forced', 'STHRNCRS', 18, 0.26),
#  (2016, 'Scheduled (Planned)', 'MUND', 18, 3.53),
#  (2016, 'Consequential', 'EUCT', 17, 0.41),
#  (2017, 'Opportunistic Maintenance (Planned)', 'MELK', 16, 0.65),
#  (2016, 'Scheduled (Planned)', 'PUG', 16, 1.47),
#  (2017, 'Scheduled (Planned)', 'KORL', 16, 3.38),
#  (2016, 'Consequential', 'ENRG', 15, 0.57),
#  (2017, 'Forced', 'MUND', 15, 0.19),
#  (2017, 'Consequential', 'EUCT', 14, 0.32),
#  (2016, 'Opportunistic Maintenance (Planned)', 'KORL', 14, 0.22),
#  (2017, 'Scheduled (Planned)', 'STHRNCRS', 14, 0.68),
#  (2016, 'Forced', 'STHRNCRS', 13, 0.33),
#  (2017, 'Opportunistic Maintenance (Planned)', 'GW', 13, 0.28),
#  (2016, 'Scheduled (Planned)', 'STHRNCRS', 13, 0.62),
#  (2016, 'Consequential', 'COLLGAR', 12, 0.6),
#  (2017, 'Consequential', 'DNHR', 12, 0.24),
#  (2017, 'Forced', 'MCG', 12, 0.28),
#  (2016, 'Scheduled (Planned)', 'COLLGAR', 12, 4.28),
#  (2017, 'Scheduled (Planned)', 'PMC', 12, 1.7),
#  (2016, 'Consequential', 'DNHR', 11, 0.28),
#  (2016, 'Forced', 'EUCT', 11, 5.9),
#  (2017, 'Scheduled (Planned)', 'PUG', 11, 2.25),
#  (2016, 'Consequential', 'PMC', 10, 0.28),
#  (2017, 'Opportunistic Maintenance (Planned)', 'KORL', 10, 0.24),
#  (2016, 'Consequential', 'STHRNCRS', 9, 0.22),
#  (2017, 'Opportunistic Maintenance (Planned)', 'MUND', 9, 0.21),
#  (2017, 'Scheduled (Planned)', 'COLLGAR', 9, 6.36),
#  (2017, 'Consequential', 'PMC', 8, 3.52),
#  (2017, 'Forced', 'WGUTD', 8, 3.44),
#  (2016, 'Opportunistic Maintenance (Planned)', 'MUND', 8, 0.15),
#  (2016, 'Consequential', 'MELK', 7, 0.76),
#  (2017, 'Consequential', 'ENRG', 7, 0.27),
#  (2017, 'Forced', 'ENRG', 7, 0.26),
#  (2016, 'Opportunistic Maintenance (Planned)', 'PUG', 7, 0.21),
#  (2017, 'Scheduled (Planned)', 'MUND', 7, 1.7),
#  (2016, 'Consequential', 'WGUTD', 6, 1.99),
#  (2017, 'Consequential', 'KORL', 6, 2.24),
#  (2017, 'Consequential', 'COLLGAR', 5, 0.23),
#  (2017, 'Opportunistic Maintenance (Planned)', 'COLLGAR', 5, 0.33),
#  (2016, 'Scheduled (Planned)', 'TRMOS', 5, 1.42),
#  (2017, 'Consequential', 'GW', 4, 0.24),
#  (2016, 'Forced', 'MUND', 4, 0.37),
#  (2017, 'Forced', 'TSLA_MGT', 4, 0.31),
#  (2016, 'Opportunistic Maintenance (Planned)', 'ENRG', 4, 0.47),
#  (2017, 'Scheduled (Planned)', 'MCG', 4, 0.06),
#  (2017, 'Scheduled (Planned)', 'TRMOS', 4, 2.31),
#  (2017, 'Forced', 'EUCT', 3, 0.03),
#  (2016, 'Opportunistic Maintenance (Planned)', 'AURICON', 3, 0.33),
#  (2017, 'Opportunistic Maintenance (Planned)', 'ENRG', 3, 0.35),
#  (2017, 'Opportunistic Maintenance (Planned)', 'PUG', 3, 0.24),
#  (2016, 'Consequential', 'MCG', 2, 0.26),
#  (2017, 'Consequential', 'MCG', 2, 0.23),
#  (2017, 'Consequential', 'STHRNCRS', 2, 0.26),
#  (2016, 'Forced', 'TSLA_MGT', 2, 0.25),
#  (2016, 'Forced', 'WGUTD', 2, 0.02),
#  (2017, 'Opportunistic Maintenance (Planned)', 'WGUTD', 2, 0.05),
#  (2016, 'Scheduled (Planned)', 'AUXC', 2, 1.25),
#  (2016, 'Consequential', 'AUXC', 1, 0.96),
#  (2017, 'Consequential', 'AUXC', 1, 0.1),
#  (2017, 'Consequential', 'WGUTD', 1, 0.04),
#  (2016, 'Forced', 'DNHR', 1, 0.4),
#  (2016, 'Forced', 'MCG', 1, 0.79),
#  (2017, 'Forced', 'DNHR', 1, 0.48),
#  (2016, 'Opportunistic Maintenance (Planned)', 'PMC', 1, 0.08),
#  (2016, 'Opportunistic Maintenance (Planned)', 'TRMOS', 1, 0.06),
#  (2016, 'Opportunistic Maintenance (Planned)', 'WGUTD', 1, 0.6),
#  (2017, 'Opportunistic Maintenance (Planned)', 'PMC', 1, 0.25),
#  (2017, 'Opportunistic Maintenance (Planned)', 'STHRNCRS', 1, 0.06),
#  (2016, 'Scheduled (Planned)', 'MCG', 1, 1.42),
#  (2017, 'Scheduled (Planned)', 'AUXC', 1, 2.88),
#  (2017, 'Scheduled (Planned)', 'WGUTD', 1, 10.58)]

# %% [markdown]
# Now we're getting somewhere...!
# We've identified participants who are having many outages, as well as participants who have been offline for the longest durations.
#
# Armed with this information, it's important we're able to classify our participants accordingly based on reliability metrics of uptime.
#
# Let's perform risk classification for each participant based off the following criteria:
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day)</li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours</li>
# </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Four </h3>

# %% [markdown]
# <b> Using the above criteria for context, write a SQL Statement that <u> classifies each participant code as either `High Risk`, `Medium Risk` or `Low Risk` in a column called `Risk_Classification`</u> that is based off their Average Outage Duration Time. Please note that this is for all valid (i.e. `Where status = approved`) outage types (Forced, Consequential, Scheduled, Opportunistic) for <u>all</u> participant codes from 2016 to 2017.

# %%
# %%sql
# WITH CTE as (
#     SELECT
#         Year,
#         Outage_Reason,
#         Participant_Code,
#         count(*) Total_Number_Outages,
#         ROUND(AVG(ABS(JULIANDAY(Start_Time) - JULIANDAY(End_Time))),2) as Average_Outage_Duration_In_Days
#     FROM
#         AEMR_Outage_Table
#     WHERE
#         Status = 'Approved'
#     GROUP BY
#         Year, Outage_Reason, Participant_Code
# )
# SELECT *,
#     CASE
#         WHEN Average_Outage_Duration_In_Days < .5 THEN 'Low Risk'
#         WHEN Average_Outage_Duration_In_Days > 1 THEN 'High Risk'
#         ELSE 'Medium Risk'
#     END AS Risk_Classification
# FROM
#     CTE
# ORDER BY Average_Outage_Duration_In_Days DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2017, 'Scheduled (Planned)', 'WGUTD', 1, 10.58, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'KORL', 20, 6.96, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'MELK', 70, 6.89, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'COLLGAR', 9, 6.36, 'High Risk'),
#  (2016, 'Forced', 'EUCT', 11, 5.9, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'ENRG', 37, 4.96, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'ENRG', 29, 4.85, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'MELK', 85, 4.61, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'GW', 45, 4.43, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'COLLGAR', 12, 4.28, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'MUND', 18, 3.53, 'High Risk'),
#  (2017, 'Consequential', 'PMC', 8, 3.52, 'High Risk'),
#  (2017, 'Forced', 'WGUTD', 8, 3.44, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'KORL', 16, 3.38, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'AUXC', 1, 2.88, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'GW', 26, 2.65, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'PJRH', 35, 2.61, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'PJRH', 38, 2.37, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'TRMOS', 4, 2.31, 'High Risk'),
#  (2017, 'Forced', 'MELK', 177, 2.28, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'PUG', 11, 2.25, 'High Risk'),
#  (2016, 'Forced', 'ENRG', 21, 2.24, 'High Risk'),
#  (2017, 'Consequential', 'KORL', 6, 2.24, 'High Risk'),
#  (2016, 'Consequential', 'WGUTD', 6, 1.99, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'TSLA_MGT', 23, 1.97, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'PMC', 27, 1.9, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'AURICON', 46, 1.89, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'MUND', 7, 1.7, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'PMC', 12, 1.7, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'PUG', 16, 1.47, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'AURICON', 45, 1.45, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'MCG', 1, 1.42, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'TRMOS', 5, 1.42, 'High Risk'),
#  (2017, 'Forced', 'COLLGAR', 45, 1.38, 'High Risk'),
#  (2016, 'Scheduled (Planned)', 'AUXC', 2, 1.25, 'High Risk'),
#  (2016, 'Forced', 'PJRH', 81, 1.22, 'High Risk'),
#  (2017, 'Forced', 'KORL', 76, 1.21, 'High Risk'),
#  (2016, 'Forced', 'COLLGAR', 29, 1.11, 'High Risk'),
#  (2017, 'Forced', 'GW', 227, 1.06, 'High Risk'),
#  (2017, 'Scheduled (Planned)', 'TSLA_MGT', 28, 0.99, 'Medium Risk'),
#  (2016, 'Consequential', 'AUXC', 1, 0.96, 'Medium Risk'),
#  (2016, 'Forced', 'PUG', 24, 0.92, 'Medium Risk'),
#  (2017, 'Forced', 'PJRH', 72, 0.84, 'Medium Risk'),
#  (2016, 'Forced', 'MELK', 157, 0.83, 'Medium Risk'),
#  (2016, 'Forced', 'MCG', 1, 0.79, 'Medium Risk'),
#  (2016, 'Consequential', 'MELK', 7, 0.76, 'Medium Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'MELK', 24, 0.71, 'Medium Risk'),
#  (2017, 'Scheduled (Planned)', 'STHRNCRS', 14, 0.68, 'Medium Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'MELK', 16, 0.65, 'Medium Risk'),
#  (2016, 'Scheduled (Planned)', 'STHRNCRS', 13, 0.62, 'Medium Risk'),
#  (2016, 'Consequential', 'COLLGAR', 12, 0.6, 'Medium Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'WGUTD', 1, 0.6, 'Medium Risk'),
#  (2016, 'Consequential', 'ENRG', 15, 0.57, 'Medium Risk'),
#  (2016, 'Forced', 'PMC', 69, 0.49, 'Low Risk'),
#  (2017, 'Forced', 'DNHR', 1, 0.48, 'Low Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'ENRG', 4, 0.47, 'Low Risk'),
#  (2016, 'Consequential', 'TSLA_MGT', 30, 0.44, 'Low Risk'),
#  (2017, 'Forced', 'TRMOS', 172, 0.42, 'Low Risk'),
#  (2016, 'Consequential', 'EUCT', 17, 0.41, 'Low Risk'),
#  (2016, 'Forced', 'DNHR', 1, 0.4, 'Low Risk'),
#  (2016, 'Forced', 'GW', 317, 0.38, 'Low Risk'),
#  (2016, 'Forced', 'KORL', 53, 0.38, 'Low Risk'),
#  (2016, 'Forced', 'MUND', 4, 0.37, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'ENRG', 3, 0.35, 'Low Risk'),
#  (2017, 'Consequential', 'TSLA_MGT', 23, 0.34, 'Low Risk'),
#  (2016, 'Forced', 'STHRNCRS', 13, 0.33, 'Low Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'AURICON', 3, 0.33, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'COLLGAR', 5, 0.33, 'Low Risk'),
#  (2017, 'Consequential', 'EUCT', 14, 0.32, 'Low Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'GW', 20, 0.31, 'Low Risk'),
#  (2017, 'Forced', 'TSLA_MGT', 4, 0.31, 'Low Risk'),
#  (2016, 'Consequential', 'DNHR', 11, 0.28, 'Low Risk'),
#  (2016, 'Consequential', 'PMC', 10, 0.28, 'Low Risk'),
#  (2017, 'Forced', 'MCG', 12, 0.28, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'GW', 13, 0.28, 'Low Risk'),
#  (2017, 'Consequential', 'ENRG', 7, 0.27, 'Low Risk'),
#  (2016, 'Consequential', 'MCG', 2, 0.26, 'Low Risk'),
#  (2017, 'Consequential', 'STHRNCRS', 2, 0.26, 'Low Risk'),
#  (2017, 'Forced', 'ENRG', 7, 0.26, 'Low Risk'),
#  (2017, 'Forced', 'STHRNCRS', 18, 0.26, 'Low Risk'),
#  (2016, 'Forced', 'TSLA_MGT', 2, 0.25, 'Low Risk'),
#  (2017, 'Forced', 'PUG', 135, 0.25, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'PMC', 1, 0.25, 'Low Risk'),
#  (2017, 'Consequential', 'DNHR', 12, 0.24, 'Low Risk'),
#  (2017, 'Consequential', 'GW', 4, 0.24, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'KORL', 10, 0.24, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'PJRH', 39, 0.24, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'PUG', 3, 0.24, 'Low Risk'),
#  (2017, 'Consequential', 'COLLGAR', 5, 0.23, 'Low Risk'),
#  (2017, 'Consequential', 'MCG', 2, 0.23, 'Low Risk'),
#  (2016, 'Consequential', 'STHRNCRS', 9, 0.22, 'Low Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'KORL', 14, 0.22, 'Low Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'PUG', 7, 0.21, 'Low Risk'),
#  (2017, 'Consequential', 'AURICON', 42, 0.21, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'MUND', 9, 0.21, 'Low Risk'),
#  (2016, 'Forced', 'TRMOS', 65, 0.19, 'Low Risk'),
#  (2017, 'Forced', 'MUND', 15, 0.19, 'Low Risk'),
#  (2016, 'Consequential', 'GW', 20, 0.18, 'Low Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'PJRH', 23, 0.18, 'Low Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'MUND', 8, 0.15, 'Low Risk'),
#  (2016, 'Consequential', 'AURICON', 41, 0.13, 'Low Risk'),
#  (2017, 'Consequential', 'AUXC', 1, 0.1, 'Low Risk'),
#  (2016, 'Forced', 'AUXC', 206, 0.08, 'Low Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'PMC', 1, 0.08, 'Low Risk'),
#  (2016, 'Forced', 'AURICON', 208, 0.07, 'Low Risk'),
#  (2017, 'Forced', 'AURICON', 490, 0.07, 'Low Risk'),
#  (2016, 'Opportunistic Maintenance (Planned)', 'TRMOS', 1, 0.06, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'STHRNCRS', 1, 0.06, 'Low Risk'),
#  (2017, 'Scheduled (Planned)', 'MCG', 4, 0.06, 'Low Risk'),
#  (2017, 'Opportunistic Maintenance (Planned)', 'WGUTD', 2, 0.05, 'Low Risk'),
#  (2017, 'Consequential', 'WGUTD', 1, 0.04, 'Low Risk'),
#  (2017, 'Forced', 'PMC', 40, 0.04, 'Low Risk'),
#  (2017, 'Forced', 'EUCT', 3, 0.03, 'Low Risk'),
#  (2016, 'Forced', 'WGUTD', 2, 0.02, 'Low Risk'),
#  (2017, 'Forced', 'AUXC', 120, 0.02, 'Low Risk')]

# %% [markdown]
# Now that we've classified our participants as either `High Risk`, `Medium Risk` or `Low Risk`, we want to dig a little deeper.
#
# Does it make sense that `Consequential`, `Opportunistic` or `Planned` aren't considered regarding the Risk Category?
#
# Perhaps we should refine our category accordingly by ensuring we focus our Risk Category on labelling only `Forced` Outages as being a Risk. After all, Forced Outages are the unplanned outages that risk the security of the electricity grid.
#
# Let's add two additional criteria to our classification considering `Total Number of Outage Events` and `Outage Type`.
#
# We've summarised these below:
#
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day) OR the Total Number of Outage Events > 20 </li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours OR the Total Number of Outage Events is Between 10 and 20 </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours OR the Total Number of Outage Events < 10 </li>
# <li> If Outage Type is not forced, then N/A
# </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Five </h3>

# %% [markdown]
# <b> Just as you did in Question Four, Using the above criteria for context, write a SQL Statement that <u> classifies each participant code as either `High Risk`, `Medium Risk` or `Low Risk` in a column called `Risk_Classification`</u> using the new classification criteria. Order the results using `Average Duration Time In Days` in descending order.

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# WITH CTE AS (
#     SELECT
#         Year,
#         Outage_Reason,
#         Participant_Code,
#         count(*) AS Total_Number_Outages,
#         ROUND(AVG(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))), 2) AS Average_Outage_Duration_In_Days
#     FROM
#         AEMR_Outage_Table
#     WHERE
#         Status = 'Approved'
#         AND Outage_Reason = 'Forced'
#     GROUP BY
#         Year, Outage_Reason, Participant_Code
# )
# SELECT
#     *,
#     CASE
#         WHEN Outage_Reason = 'Forced' THEN
#             CASE
#                 WHEN Average_Outage_Duration_In_Days < 0.5 OR Total_Number_Outages < 10 THEN 'Low Risk'
#                 WHEN Average_Outage_Duration_In_Days > 1 OR Total_Number_Outages > 20 THEN 'High Risk'
#                 ELSE 'Medium Risk'
#             END
#         ELSE 'N/A'
#     END AS Risk_Classification
# FROM
#     CTE
# ORDER BY Average_Outage_Duration_In_Days DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 'Forced', 'EUCT', 11, 5.9, 'High Risk'),
#  (2017, 'Forced', 'WGUTD', 8, 3.44, 'Low Risk'),
#  (2017, 'Forced', 'MELK', 177, 2.28, 'High Risk'),
#  (2016, 'Forced', 'ENRG', 21, 2.24, 'High Risk'),
#  (2017, 'Forced', 'COLLGAR', 45, 1.38, 'High Risk'),
#  (2016, 'Forced', 'PJRH', 81, 1.22, 'High Risk'),
#  (2017, 'Forced', 'KORL', 76, 1.21, 'High Risk'),
#  (2016, 'Forced', 'COLLGAR', 29, 1.11, 'High Risk'),
#  (2017, 'Forced', 'GW', 227, 1.06, 'High Risk'),
#  (2016, 'Forced', 'PUG', 24, 0.92, 'High Risk'),
#  (2017, 'Forced', 'PJRH', 72, 0.84, 'High Risk'),
#  (2016, 'Forced', 'MELK', 157, 0.83, 'High Risk'),
#  (2016, 'Forced', 'MCG', 1, 0.79, 'Low Risk'),
#  (2016, 'Forced', 'PMC', 69, 0.49, 'Low Risk'),
#  (2017, 'Forced', 'DNHR', 1, 0.48, 'Low Risk'),
#  (2017, 'Forced', 'TRMOS', 172, 0.42, 'Low Risk'),
#  (2016, 'Forced', 'DNHR', 1, 0.4, 'Low Risk'),
#  (2016, 'Forced', 'GW', 317, 0.38, 'Low Risk'),
#  (2016, 'Forced', 'KORL', 53, 0.38, 'Low Risk'),
#  (2016, 'Forced', 'MUND', 4, 0.37, 'Low Risk'),
#  (2016, 'Forced', 'STHRNCRS', 13, 0.33, 'Low Risk'),
#  (2017, 'Forced', 'TSLA_MGT', 4, 0.31, 'Low Risk'),
#  (2017, 'Forced', 'MCG', 12, 0.28, 'Low Risk'),
#  (2017, 'Forced', 'ENRG', 7, 0.26, 'Low Risk'),
#  (2017, 'Forced', 'STHRNCRS', 18, 0.26, 'Low Risk'),
#  (2016, 'Forced', 'TSLA_MGT', 2, 0.25, 'Low Risk'),
#  (2017, 'Forced', 'PUG', 135, 0.25, 'Low Risk'),
#  (2016, 'Forced', 'TRMOS', 65, 0.19, 'Low Risk'),
#  (2017, 'Forced', 'MUND', 15, 0.19, 'Low Risk'),
#  (2016, 'Forced', 'AUXC', 206, 0.08, 'Low Risk'),
#  (2016, 'Forced', 'AURICON', 208, 0.07, 'Low Risk'),
#  (2017, 'Forced', 'AURICON', 490, 0.07, 'Low Risk'),
#  (2017, 'Forced', 'PMC', 40, 0.04, 'Low Risk'),
#  (2017, 'Forced', 'EUCT', 3, 0.03, 'Low Risk'),
#  (2016, 'Forced', 'WGUTD', 2, 0.02, 'Low Risk'),
#  (2017, 'Forced', 'AUXC', 120, 0.02, 'Low Risk')]

# %% [markdown]
# <h3 style="color:#D4AF37"> ⚡ Part II. Energy Losses & Market Reliability ⚡ </h3>

# %% [markdown]
# When an energy provider provides energy to the market, they are making a commitment to the market and saying; “We will supply X amount of energy to the market under a contractual obligation.” However, in a situation where the outages are Forced, the energy provider intended to provide energy but are unable to provide energy and are forced offline. <b style="color:Maroon">If many energy providers are forced offline at the same time it could cause an energy security risk that AEMR needs to mitigate. </b>
#
# To ensure this doesn’t happen, the AEMR is interested in exploring the following questions:
#
# <li> Of the outage types in 2016 and 2017, what percent were Forced Outage(s)?
# <li> What was the average duration for a forced outage during both 2016 and 2017? Have we seen an increase in the average duration of forced outages?
# <li> Which energy providers tended to have the largest number of forced outages?
#
# <p>
#
#
# <img src = "https://media.istockphoto.com/id/1281821795/photo/market-stock-graph-and-information-with-city-light-and-electricity-and-energy-facility-banner.jpg?s=612x612&w=0&k=20&c=RSN5LqeMW28HW10aA190_DWR5YJ5tG2wixHFPBV3uZE=">

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Six </h3>

# %% [markdown]
# <b> Write a SQL Statement to calculate the proportion of Forced Outages that have occurred over the 2016 - 2017 Period.
# Do we observe any particular increases regarding any Outage Types over this period? </b>

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# WITH CTE AS (
#     SELECT
#         Year,
#         COUNT(*) AS Total_Number_Outages,
#         SUM(CASE WHEN Outage_Reason LIKE "%Forced" THEN 1 ELSE 0 END) AS Total_Number_Forced_Outages
#     FROM
#         AEMR_Outage_Table
#     WHERE
#         Status = 'Approved'
#     GROUP BY Year
# )
# SELECT
#     *,
#     ROUND((Total_Number_Forced_Outages * 1.0 / Total_Number_Outages) * 100, 2) AS Pct_Forced_Outage
# FROM
#     CTE;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 1931, 1264, 65.46), (2017, 2171, 1622, 74.71)]

# %% [markdown]
# Great. It's clear to see now that `Forced Outages` are problematic for us. Not only are they the only outage type that generates financial losses as the Outage is unplanned, it seems there is a number of Energy Participants who have been having a significantly high number of Outages.
#
# Now what can we do about this?
#
# Let's break our analysis down into Macro and Micro Analysis.
# The total gives us the Overall Duration a participant is offline / has lost energy, however, it doesn't tell us how *frequently* this occurs. In other words, if we have one or two very big outages, it might contribute to very large totals.
#
# However, perhaps an <b> average </b> can help us identify how big these Outages might really be, spread across the year!

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Seven </h3>

# %% [markdown]
# Write a SQL Statement to calculate the `Total Number of Outages`, `Total Duration In Days`and `Total Energy Lost` of all valid `Outages` for each `participant code` and `facility_code`, sorted by `Total Energy Lost` in descending order and Ordered by the YEAR Category.

# %%
# %%sql
# SELECT
#     Year,
#     Participant_Code,
#     Facility_Code,
#     Outage_Reason,
#     COUNT(*) as Total_Number_Outages,
#     ROUND(SUM(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2) AS Total_Outage_Duration_In_Days,
#     ROUND(SUM(Energy_Lost_MW),2) AS Total_Energy_Lost
# FROM
#     AEMR_Outage_Table
# WHERE
#     Status = 'Approved'
# GROUP BY
#     Year, Participant_Code, Facility_Code, Outage_Reason
# ORDER BY
#     Year;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 'AURICON', 'AURICON_PNJ_U1', 'Consequential', 41, 5.31, 3925.55),
#  (2016, 'AURICON', 'AURICON_PNJ_U1', 'Forced', 208, 15.06, 10696.28),
#  (2016, 'AURICON', 'AURICON_PNJ_U1', 'Opportunistic Maintenance (Planned)', 3, 0.98, 523.0),
#  (2016, 'AURICON', 'AURICON_PNJ_U1', 'Scheduled (Planned)', 46, 87.02, 6964.8),
#  (2016, 'AUXC', 'AUXC_WGP', 'Consequential', 1, 0.96, 25.0),
#  (2016, 'AUXC', 'AUXC_WGP', 'Forced', 206, 16.04, 2734.14),
#  (2016, 'AUXC', 'AUXC_WGP', 'Scheduled (Planned)', 2, 2.5, 50.0),
#  (2016, 'COLLGAR', 'COLLGAR_WF1', 'Consequential', 12, 7.15, 1374.0),
#  (2016, 'COLLGAR', 'COLLGAR_WF1', 'Forced', 29, 32.33, 4320.86),
#  (2016, 'COLLGAR', 'COLLGAR_WF1', 'Scheduled (Planned)', 12, 51.38, 2139.87),
#  (2016, 'DNHR', 'DNHR_DENMARK_WF1', 'Consequential', 11, 3.12, 15.84),
#  (2016, 'DNHR', 'DNHR_DENMARK_WF1', 'Forced', 1, 0.4, 1.44),
#  (2016, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Consequential', 15, 8.48, 161.4),
#  (2016, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Forced', 21, 47.04, 1182.8),
#  (2016, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Opportunistic Maintenance (Planned)', 4, 1.9, 87.0),
#  (2016, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Scheduled (Planned)', 29, 140.6, 445.6),
#  (2016, 'EUCT', 'GRASMERE_WF1', 'Consequential', 17, 6.96, 290.4),
#  (2016, 'EUCT', 'GRASMERE_WF1', 'Forced', 11, 64.9, 64.8),
#  (2016, 'GW', 'BW1_GREENWATERS_G2', 'Consequential', 20, 3.6, 832.72),
#  (2016, 'GW', 'BW1_GREENWATERS_G2', 'Forced', 317, 120.6, 15751.38),
#  (2016, 'GW', 'BW1_GREENWATERS_G2', 'Opportunistic Maintenance (Planned)', 20, 6.21, 2951.0),
#  (2016, 'GW', 'BW1_GREENWATERS_G2', 'Scheduled (Planned)', 45, 199.4, 6450.0),
#  (2016, 'KORL', 'KORL_GT3', 'Forced', 53, 20.0, 4040.32),
#  (2016, 'KORL', 'KORL_GT3', 'Opportunistic Maintenance (Planned)', 14, 3.04, 1172.05),
#  (2016, 'KORL', 'KORL_GT3', 'Scheduled (Planned)', 20, 139.25, 1685.6),
#  (2016, 'MCG', 'MWF_MUMBIDA_WF1', 'Consequential', 2, 0.52, 110.0),
#  (2016, 'MCG', 'MWF_MUMBIDA_WF1', 'Forced', 1, 0.79, 55.0),
#  (2016, 'MCG', 'MWF_MUMBIDA_WF1', 'Scheduled (Planned)', 1, 1.42, 55.0),
#  (2016, 'MELK', 'MELK_G7', 'Consequential', 7, 5.35, 1524.82),
#  (2016, 'MELK', 'MELK_G7', 'Forced', 157, 129.6, 13771.07),
#  (2016, 'MELK', 'MELK_G7', 'Opportunistic Maintenance (Planned)', 24, 17.0, 2877.04),
#  (2016, 'MELK', 'MELK_G7', 'Scheduled (Planned)', 85, 392.25, 9668.79),
#  (2016, 'MUND', 'MUNDARING_GT1', 'Forced', 4, 1.48, 147.2),
#  (2016, 'MUND', 'MUNDARING_GT1', 'Opportunistic Maintenance (Planned)', 8, 1.21, 248.0),
#  (2016, 'MUND', 'MUNDARING_GT1', 'Scheduled (Planned)', 18, 63.46, 664.0),
#  (2016, 'PJRH', 'PJRH_GT11', 'Forced', 81, 98.79, 5881.52),
#  (2016, 'PJRH', 'PJRH_GT11', 'Opportunistic Maintenance (Planned)', 23, 4.21, 2178.95),
#  (2016, 'PJRH', 'PJRH_GT11', 'Scheduled (Planned)', 38, 89.9, 2445.0),
#  (2016, 'PMC', 'PMC_AG', 'Consequential', 10, 2.81, 643.0),
#  (2016, 'PMC', 'PMC_AG', 'Forced', 69, 34.06, 9093.09),
#  (2016, 'PMC', 'PMC_AG', 'Opportunistic Maintenance (Planned)', 1, 0.08, 335.0),
#  (2016, 'PMC', 'PMC_AG', 'Scheduled (Planned)', 27, 51.4, 4839.0),
#  (2016, 'PUG', 'PERTHENERGY_KORL_GT1', 'Forced', 24, 22.17, 815.47),
#  (2016, 'PUG', 'PERTHENERGY_KORL_GT1', 'Opportunistic Maintenance (Planned)', 7, 1.48, 580.0),
#  (2016, 'PUG', 'PERTHENERGY_KORL_GT1', 'Scheduled (Planned)', 16, 23.56, 1334.0),
#  (2016, 'STHRNCRS', 'STHRNCRS_EG', 'Consequential', 9, 1.94, 207.0),
#  (2016, 'STHRNCRS', 'STHRNCRS_EG', 'Forced', 13, 4.29, 299.0),
#  (2016, 'STHRNCRS', 'STHRNCRS_EG', 'Scheduled (Planned)', 13, 8.04, 299.0),
#  (2016, 'TRMOS', 'TIWEST_COG1', 'Forced', 65, 12.63, 1232.43),
#  (2016, 'TRMOS', 'TIWEST_COG1', 'Opportunistic Maintenance (Planned)', 1, 0.06, 0.0),
#  (2016, 'TRMOS', 'TIWEST_COG1', 'Scheduled (Planned)', 5, 7.08, 168.4),
#  (2016, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Consequential', 30, 13.21, 297.0),
#  (2016, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Forced', 2, 0.5, 160.0),
#  (2016, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Scheduled (Planned)', 23, 45.25, 448.8),
#  (2016, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Consequential', 6, 11.96, 198.0),
#  (2016, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Forced', 2, 0.04, 54.0),
#  (2016, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Opportunistic Maintenance (Planned)', 1, 0.6, 36.0),
#  (2017, 'AURICON', 'AURICON_PNJ_U1', 'Consequential', 42, 8.88, 2553.24),
#  (2017, 'AURICON', 'AURICON_PNJ_U1', 'Forced', 490, 33.65, 21639.55),
#  (2017, 'AURICON', 'AURICON_PNJ_U1', 'Scheduled (Planned)', 45, 65.4, 5941.25),
#  (2017, 'AUXC', 'AUXC_WGP', 'Consequential', 1, 0.1, 26.0),
#  (2017, 'AUXC', 'AUXC_WGP', 'Forced', 120, 2.1, 1768.76),
#  (2017, 'AUXC', 'AUXC_WGP', 'Scheduled (Planned)', 1, 2.88, 26.0),
#  (2017, 'COLLGAR', 'COLLGAR_WF1', 'Consequential', 5, 1.17, 926.0),
#  (2017, 'COLLGAR', 'COLLGAR_WF1', 'Forced', 45, 62.1, 2787.06),
#  (2017, 'COLLGAR', 'COLLGAR_WF1', 'Opportunistic Maintenance (Planned)', 5, 1.65, 763.96),
#  (2017, 'COLLGAR', 'COLLGAR_WF1', 'Scheduled (Planned)', 9, 57.27, 1632.78),
#  (2017, 'DNHR', 'DNHR_DENMARK_WF1', 'Consequential', 12, 2.9, 17.28),
#  (2017, 'DNHR', 'DNHR_DENMARK_WF1', 'Forced', 1, 0.48, 1.44),
#  (2017, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Consequential', 7, 1.87, 63.8),
#  (2017, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Forced', 7, 1.85, 191.86),
#  (2017, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Opportunistic Maintenance (Planned)', 3, 1.04, 24.1),
#  (2017, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Scheduled (Planned)', 37, 183.58, 516.92),
#  (2017, 'EUCT', 'GRASMERE_WF1', 'Consequential', 14, 4.52, 222.3),
#  (2017, 'EUCT', 'GRASMERE_WF1', 'Forced', 3, 0.1, 64.8),
#  (2017, 'GW', 'BW1_GREENWATERS_G2', 'Consequential', 4, 0.96, 89.29),
#  (2017, 'GW', 'BW1_GREENWATERS_G2', 'Forced', 227, 240.69, 19326.56),
#  (2017, 'GW', 'BW1_GREENWATERS_G2', 'Opportunistic Maintenance (Planned)', 13, 3.67, 1423.53),
#  (2017, 'GW', 'BW1_GREENWATERS_G2', 'Scheduled (Planned)', 26, 68.9, 3812.42),
#  (2017, 'KORL', 'KORL_GT3', 'Consequential', 6, 13.42, 505.95),
#  (2017, 'KORL', 'KORL_GT3', 'Forced', 76, 91.79, 4679.68),
#  (2017, 'KORL', 'KORL_GT3', 'Opportunistic Maintenance (Planned)', 10, 2.42, 842.8),
#  (2017, 'KORL', 'KORL_GT3', 'Scheduled (Planned)', 16, 54.1, 1326.6),
#  (2017, 'MCG', 'MWF_MUMBIDA_WF1', 'Consequential', 2, 0.46, 94.0),
#  (2017, 'MCG', 'MWF_MUMBIDA_WF1', 'Forced', 12, 3.4, 563.33),
#  (2017, 'MCG', 'MWF_MUMBIDA_WF1', 'Scheduled (Planned)', 4, 0.23, 220.0),
#  (2017, 'MELK', 'MELK_G7', 'Forced', 177, 404.15, 10285.4),
#  (2017, 'MELK', 'MELK_G7', 'Opportunistic Maintenance (Planned)', 16, 10.44, 1339.7),
#  (2017, 'MELK', 'MELK_G7', 'Scheduled (Planned)', 70, 482.58, 7499.28),
#  (2017, 'MUND', 'MUNDARING_GT1', 'Forced', 15, 2.85, 398.58),
#  (2017, 'MUND', 'MUNDARING_GT1', 'Opportunistic Maintenance (Planned)', 9, 1.9, 335.86),
#  (2017, 'MUND', 'MUNDARING_GT1', 'Scheduled (Planned)', 7, 11.9, 262.46),
#  (2017, 'PJRH', 'PJRH_GT11', 'Forced', 72, 60.13, 4839.28),
#  (2017, 'PJRH', 'PJRH_GT11', 'Opportunistic Maintenance (Planned)', 39, 9.17, 3100.95),
#  (2017, 'PJRH', 'PJRH_GT11', 'Scheduled (Planned)', 35, 91.35, 2110.01),
#  (2017, 'PMC', 'PMC_AG', 'Consequential', 8, 28.15, 1672.66),
#  (2017, 'PMC', 'PMC_AG', 'Forced', 40, 1.56, 5648.44),
#  (2017, 'PMC', 'PMC_AG', 'Opportunistic Maintenance (Planned)', 1, 0.25, 335.0),
#  (2017, 'PMC', 'PMC_AG', 'Scheduled (Planned)', 12, 20.35, 1639.2),
#  (2017, 'PUG', 'PERTHENERGY_KORL_GT1', 'Forced', 135, 33.4, 4112.1),
#  (2017, 'PUG', 'PERTHENERGY_KORL_GT1', 'Opportunistic Maintenance (Planned)', 3, 0.71, 348.0),
#  (2017, 'PUG', 'PERTHENERGY_KORL_GT1', 'Scheduled (Planned)', 11, 24.73, 1160.0),
#  (2017, 'STHRNCRS', 'STHRNCRS_EG', 'Consequential', 2, 0.52, 46.0),
#  (2017, 'STHRNCRS', 'STHRNCRS_EG', 'Forced', 18, 4.65, 292.7),
#  (2017, 'STHRNCRS', 'STHRNCRS_EG', 'Opportunistic Maintenance (Planned)', 1, 0.06, 23.0),
#  (2017, 'STHRNCRS', 'STHRNCRS_EG', 'Scheduled (Planned)', 14, 9.46, 322.0),
#  (2017, 'TRMOS', 'TIWEST_COG1', 'Forced', 172, 71.9, 5016.67),
#  (2017, 'TRMOS', 'TIWEST_COG1', 'Scheduled (Planned)', 4, 9.23, 168.4),
#  (2017, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Consequential', 23, 7.73, 227.7),
#  (2017, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Forced', 4, 1.23, 169.9),
#  (2017, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Scheduled (Planned)', 28, 27.75, 678.4),
#  (2017, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Consequential', 1, 0.04, 36.0),
#  (2017, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Forced', 8, 27.54, 221.29),
#  (2017, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Opportunistic Maintenance (Planned)', 2, 0.1, 72.0),
#  (2017, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Scheduled (Planned)', 1, 10.58, 36.0)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Eight </h3>

# %% [markdown]
# <b> Write a SQL Statement to calculate the `Average Duration In Days`and `Average Energy Lost` of all valid `FORCED OUTAGES` for each `participant code` and `facility_code` sorted by `Average Energy Lost` in descending order and Ordered by the YEAR Category.

# %% [markdown]
# <h4 style="color:Teal"> Please write your SQL in the code window below </h4>

# %%
# %%sql
# SELECT
#     Year,
#     Participant_Code,
#     Facility_Code,
#     Outage_Reason,
#     ROUND(AVG(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2) AS Avg_Duration_In_Days,
#     ROUND(AVG(Energy_Lost_MW),2) AS Avg_Energy_Lost
# FROM
#     AEMR_Outage_Table
# WHERE
#     Status = 'Approved'
#     AND Outage_Reason = 'Forced'
# GROUP BY Year, Participant_Code, Facility_Code, Outage_Reason
# ORDER BY Avg_Duration_In_Days DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 'EUCT', 'GRASMERE_WF1', 'Forced', 5.9, 5.89),
#  (2017, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Forced', 3.44, 27.66),
#  (2017, 'MELK', 'MELK_G7', 'Forced', 2.28, 58.11),
#  (2016, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Forced', 2.24, 56.32),
#  (2017, 'COLLGAR', 'COLLGAR_WF1', 'Forced', 1.38, 61.93),
#  (2016, 'PJRH', 'PJRH_GT11', 'Forced', 1.22, 72.61),
#  (2017, 'KORL', 'KORL_GT3', 'Forced', 1.21, 61.57),
#  (2016, 'COLLGAR', 'COLLGAR_WF1', 'Forced', 1.11, 149.0),
#  (2017, 'GW', 'BW1_GREENWATERS_G2', 'Forced', 1.06, 85.14),
#  (2016, 'PUG', 'PERTHENERGY_KORL_GT1', 'Forced', 0.92, 33.98),
#  (2017, 'PJRH', 'PJRH_GT11', 'Forced', 0.84, 67.21),
#  (2016, 'MELK', 'MELK_G7', 'Forced', 0.83, 87.71),
#  (2016, 'MCG', 'MWF_MUMBIDA_WF1', 'Forced', 0.79, 55.0),
#  (2016, 'PMC', 'PMC_AG', 'Forced', 0.49, 131.78),
#  (2017, 'DNHR', 'DNHR_DENMARK_WF1', 'Forced', 0.48, 1.44),
#  (2017, 'TRMOS', 'TIWEST_COG1', 'Forced', 0.42, 29.17),
#  (2016, 'DNHR', 'DNHR_DENMARK_WF1', 'Forced', 0.4, 1.44),
#  (2016, 'GW', 'BW1_GREENWATERS_G2', 'Forced', 0.38, 49.69),
#  (2016, 'KORL', 'KORL_GT3', 'Forced', 0.38, 76.23),
#  (2016, 'MUND', 'MUNDARING_GT1', 'Forced', 0.37, 36.8),
#  (2016, 'STHRNCRS', 'STHRNCRS_EG', 'Forced', 0.33, 23.0),
#  (2017, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Forced', 0.31, 42.48),
#  (2017, 'MCG', 'MWF_MUMBIDA_WF1', 'Forced', 0.28, 46.94),
#  (2017, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Forced', 0.26, 27.41),
#  (2017, 'STHRNCRS', 'STHRNCRS_EG', 'Forced', 0.26, 16.26),
#  (2016, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Forced', 0.25, 80.0),
#  (2017, 'PUG', 'PERTHENERGY_KORL_GT1', 'Forced', 0.25, 30.46),
#  (2016, 'TRMOS', 'TIWEST_COG1', 'Forced', 0.19, 18.96),
#  (2017, 'MUND', 'MUNDARING_GT1', 'Forced', 0.19, 26.57),
#  (2016, 'AUXC', 'AUXC_WGP', 'Forced', 0.08, 13.27),
#  (2016, 'AURICON', 'AURICON_PNJ_U1', 'Forced', 0.07, 51.42),
#  (2017, 'AURICON', 'AURICON_PNJ_U1', 'Forced', 0.07, 44.16),
#  (2017, 'PMC', 'PMC_AG', 'Forced', 0.04, 141.21),
#  (2017, 'EUCT', 'GRASMERE_WF1', 'Forced', 0.03, 21.6),
#  (2016, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Forced', 0.02, 27.0),
#  (2017, 'AUXC', 'AUXC_WGP', 'Forced', 0.02, 14.74)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Nine </h3>

# %% [markdown]
# <b> Write a SQL Statement to calculate the `Average Energy Lost` and `Total Energy Lost` for each `Facility Code` and `Participant Code` across both the 2016 and 2017 periods when the `Outage_Reason` is set to Forced. Upon completion of this, calculate the <u> percentage </u> of energy lost due to forced outages for each `Facility_Code`. Please ORDER the query by `Total Energy Lost` from 2016 to 2017.
#
# From your analysis, which participants have contributed the most to the Energy Lost due to Forced Outages?

# %%
# %%sql
# WITH CTE AS(
#     SELECT
#         Year,
#         Participant_Code,
#         Facility_Code,
#         Outage_Reason,
#         ROUND(AVG(ABS(Energy_Lost_MW)),2) AS Avg_Energy_Lost,
#         ROUND(SUM(Energy_Lost_MW),2) AS Total_Energy_Lost
#     FROM
#         AEMR_Outage_Table
#     WHERE
#         Status = 'Approved'
#         AND Outage_Reason = 'Forced'
#     GROUP BY Year, Participant_Code, Facility_Code, Outage_Reason
# )
# SELECT
#     *
# FROM
#     CTE
# ORDER BY Total_Energy_lost DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2017, 'AURICON', 'AURICON_PNJ_U1', 'Forced', 44.16, 21639.55),
#  (2017, 'GW', 'BW1_GREENWATERS_G2', 'Forced', 85.14, 19326.56),
#  (2016, 'GW', 'BW1_GREENWATERS_G2', 'Forced', 49.69, 15751.38),
#  (2016, 'MELK', 'MELK_G7', 'Forced', 87.71, 13771.07),
#  (2016, 'AURICON', 'AURICON_PNJ_U1', 'Forced', 51.42, 10696.28),
#  (2017, 'MELK', 'MELK_G7', 'Forced', 58.11, 10285.4),
#  (2016, 'PMC', 'PMC_AG', 'Forced', 131.78, 9093.09),
#  (2016, 'PJRH', 'PJRH_GT11', 'Forced', 72.61, 5881.52),
#  (2017, 'PMC', 'PMC_AG', 'Forced', 141.21, 5648.44),
#  (2017, 'TRMOS', 'TIWEST_COG1', 'Forced', 29.17, 5016.67),
#  (2017, 'PJRH', 'PJRH_GT11', 'Forced', 67.21, 4839.28),
#  (2017, 'KORL', 'KORL_GT3', 'Forced', 61.57, 4679.68),
#  (2016, 'COLLGAR', 'COLLGAR_WF1', 'Forced', 149.0, 4320.86),
#  (2017, 'PUG', 'PERTHENERGY_KORL_GT1', 'Forced', 30.46, 4112.1),
#  (2016, 'KORL', 'KORL_GT3', 'Forced', 76.23, 4040.32),
#  (2017, 'COLLGAR', 'COLLGAR_WF1', 'Forced', 61.93, 2787.06),
#  (2016, 'AUXC', 'AUXC_WGP', 'Forced', 13.27, 2734.14),
#  (2017, 'AUXC', 'AUXC_WGP', 'Forced', 14.74, 1768.76),
#  (2016, 'TRMOS', 'TIWEST_COG1', 'Forced', 18.96, 1232.43),
#  (2016, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Forced', 56.32, 1182.8),
#  (2016, 'PUG', 'PERTHENERGY_KORL_GT1', 'Forced', 33.98, 815.47),
#  (2017, 'MCG', 'MWF_MUMBIDA_WF1', 'Forced', 46.94, 563.33),
#  (2017, 'MUND', 'MUNDARING_GT1', 'Forced', 26.57, 398.58),
#  (2016, 'STHRNCRS', 'STHRNCRS_EG', 'Forced', 23.0, 299.0),
#  (2017, 'STHRNCRS', 'STHRNCRS_EG', 'Forced', 16.26, 292.7),
#  (2017, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Forced', 27.66, 221.29),
#  (2017, 'ENRG', 'ENRG_KALGOORLIE_GT3', 'Forced', 27.41, 191.86),
#  (2017, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Forced', 42.48, 169.9),
#  (2016, 'TSLA_MGT', 'TESLA_PICTON_G1', 'Forced', 80.0, 160.0),
#  (2016, 'MUND', 'MUNDARING_GT1', 'Forced', 36.8, 147.2),
#  (2016, 'EUCT', 'GRASMERE_WF1', 'Forced', 5.89, 64.8),
#  (2017, 'EUCT', 'GRASMERE_WF1', 'Forced', 21.6, 64.8),
#  (2016, 'MCG', 'MWF_MUMBIDA_WF1', 'Forced', 55.0, 55.0),
#  (2016, 'WGUTD', 'WEST_KALGOORLIE_GT2', 'Forced', 27.0, 54.0),
#  (2016, 'DNHR', 'DNHR_DENMARK_WF1', 'Forced', 1.44, 1.44),
#  (2017, 'DNHR', 'DNHR_DENMARK_WF1', 'Forced', 1.44, 1.44)]

# %% [markdown]
# <h3 style="color:#D4AF37"> Question Ten </h3>

# %% [markdown]
# <b>Having identified the top 3 participants by Total Energy Loss being `GW`, `MELK` and `Auricon`; Write a SQL Statement calculating the `Total_Energy_Lost` each of these three `Participant_Codes` and the `Facility_Code`. Additionally, identify the `Description_Of_Outage` associated with the highest `Total_Energy_Lost` for each of the `Participant_Codes` and `Facility_Code` for each of the three participants.
#
# <u>Lastly, calculate the percentage of Energy Loss, attributed to these reasons!</u> </b>

# %%
# %%sql
# WITH Total_Energy AS (
#     SELECT
#         ROUND(SUM(Energy_Lost_MW),2) AS Grand_Total_Loss
#     FROM
#         AEMR_Outage_Table
#     WHERE
#         Status = 'Approved'
#         AND Outage_Reason = 'Forced'
# )
# SELECT
#     A.Participant_Code,
#     A.Facility_Code,
#     A.Description_Of_Outage,
#     ROUND(SUM(A.Energy_Lost_MW),2) AS Total_Energy_Loss,
#     ROUND((SUM(A.Energy_Lost_MW) / T.Grand_Total_Loss) * 100, 2) AS Pct_Energy_Loss_Overall
# FROM
#     AEMR_Outage_Table A
# CROSS JOIN
#     Total_Energy T
# WHERE
#     A.Status = 'Approved'
#     AND A.Outage_Reason = 'Forced'
#     AND A.Participant_Code IN ('AURICON', 'MELK', 'GW')
# GROUP BY
#     A.Participant_Code,
#     A.Facility_Code,
#     A.Description_Of_Outage
# ORDER BY
#     Total_Energy_Loss DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('GW', 'BW1_GREENWATERS_G2', 'Operational Issues caused real time forced outage.', 28687.54, 18.84),
#  ('AURICON', 'AURICON_PNJ_U1', 'Full unit trip', 6033.87, 3.96),
#  ('AURICON', 'AURICON_PNJ_U1', 'Return to service from outage delayed', 1573.0, 1.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'unit maximum output was restricted to 100 MW as-generated due to high rotor temperature alarm for safety purposes', 1167.73, 0.77),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 vibration issues during start-up sequence.', 1140.0, 0.75),
#  ('MELK', 'MELK_G7', 'Safety Issues', 1100.0, 0.72),
#  ('MELK', 'MELK_G7', 'Unit trip - loss of ignition at low load', 972.18, 0.64),
#  ('GW', 'BW1_GREENWATERS_G2', 'FO', 833.6, 0.55),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up.', 676.94, 0.44),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit RTS & ramp-up delayed due to reset of overspeed tripping solenoid.', 564.53, 0.37),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit trip', 530.27, 0.35),
#  ('AURICON', 'AURICON_PNJ_U1', 'Wagerup unit 2 trip, control fault', 499.64, 0.33),
#  ('GW', 'BW1_GREENWATERS_G2', 'FO due to unit trip', 473.2, 0.31),
#  ('AURICON', 'AURICON_PNJ_U1', 'Pinjarra Unit 2 ramping up from an outage', 472.19, 0.31),
#  ('AURICON', 'AURICON_PNJ_U1', 'Limited output due to ambient conditions (High temperature)', 460.4, 0.3),
#  ('MELK', 'MELK_G7', 'Boiler inspection', 422.22, 0.28),
#  ('MELK', 'MELK_G7', 'Boiler Repairs', 422.0, 0.28),
#  ('MELK', 'MELK_G7', 'Unit MFT/MTR', 422.0, 0.28),
#  ('AURICON', 'AURICON_PNJ_U1', 'Pinjarra Unit 2 tripped due to blade path temperature deviation', 419.99, 0.28),
#  ('MELK', 'MELK_G7', 'Delayed RTS', 416.9, 0.27),
#  ('MELK', 'MELK_G7', 'Delayed Unit RTS.', 411.8, 0.27),
#  ('MELK', 'MELK_G7', 'Governor Control Issues.', 411.8, 0.27),
#  ('MELK', 'MELK_G7', 'Unit MTR.', 411.8, 0.27),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up', 384.4, 0.25),
#  ('AURICON', 'AURICON_PNJ_U1', 'A-inspection outage extended', 380.0, 0.25),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit trip due to high combustion pulsation', 380.0, 0.25),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP GT delayed ramp-up due to start failure.', 374.25, 0.25),
#  ('AURICON', 'AURICON_PNJ_U1', 'Protective load shed trip', 365.02, 0.24),
#  ('AURICON', 'AURICON_PNJ_U1', 'Operational issues caused real time forced outage.', 362.41, 0.24),
#  ('GW', 'BW1_GREENWATERS_G2', 'Unit failed to start', 353.6, 0.23),
#  ('GW', 'BW1_GREENWATERS_G2', 'Unit tripped', 348.4, 0.23),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U1 max output reduced due to ambient conditions.', 348.27, 0.23),
#  ('MELK', 'MELK_G7', 'Loss off fire to the boiler resulting in pressure drop', 347.26, 0.23),
#  ('MELK', 'MELK_G7', 'Delay in RTS from planned outage', 343.24, 0.23),
#  ('MELK', 'MELK_G7', 'Forced full outage due to Air Compressor issues', 343.24, 0.23),
#  ('MELK', 'MELK_G7', 'Full forced outage due to boiler feed pump trip', 343.24, 0.23),
#  ('MELK', 'MELK_G7', 'Full forced outage due to unit trip.', 343.24, 0.23),
#  ('MELK', 'MELK_G7', 'Full forced outage for RAH repairs', 343.24, 0.23),
#  ('MELK', 'MELK_G7', 'Rotary air heater wash', 343.24, 0.23),
#  ('MELK', 'MELK_G7', 'Unit trip due to hydraulic fault', 343.24, 0.23),
#  ('MELK', 'MELK_G7', 'Unit tripped - LP heater level', 343.24, 0.23),
#  ('MELK', 'MELK_G7', 'forced outage due to unit trip', 343.24, 0.23),
#  ('GW', 'BW1_GREENWATERS_G2', 'Gas Regulation issue', 342.0, 0.22),
#  ('MELK', 'MELK_G7', 'Temperature related issues on ramp up', 339.69, 0.22),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to precip fault', 320.0, 0.21),
#  ('MELK', 'MELK_G7', 'Partial forced outage during turbine valve testing', 314.28, 0.21),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP1 gas control valve erratic, unit offline to reset/restart', 312.76, 0.21),
#  ('MELK', 'MELK_G7', 'Pro-rata forced outage: Unit trip during turbine valve testing', 312.0, 0.2),
#  ('AURICON', 'AURICON_PNJ_U1', 'Plant failed to reach target due to operational issue.', 309.65, 0.2),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit had problems ramping up and staying to min load', 303.84, 0.2),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ1 max output reduced due to ambient conditions.', 298.51, 0.2),
#  ('MELK', 'MELK_G7', 'Pro rata outage due to air compressor issues', 297.47, 0.2),
#  ('MELK', 'MELK_G7', 'Pro-rata forced outage delay in return to service', 297.47, 0.2),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output limited due to ambient condition.', 296.04, 0.19),
#  ('MELK', 'MELK_G7', 'Full forced outage (pro-rata) due to boiler feed pump trip', 295.62, 0.19),
#  ('AURICON', 'AURICON_PNJ_U1', 'Ambient temperature, capacity limit', 293.81, 0.19),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp on start up', 290.37, 0.19),
#  ('MELK', 'MELK_G7', 'Unit run back due to thermocouple fault.', 287.58, 0.19),
#  ('AURICON', 'AURICON_PNJ_U1', 'Late ramp up', 287.03, 0.19),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit is unavailable after tripping on return to service.\n', 286.0, 0.19),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Contractor tuning requirement\n', 267.8, 0.18),
#  ('MELK', 'MELK_G7', 'Boiler Tube Leak Repairs', 266.0, 0.17),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation during ramp up from outage', 264.91, 0.17),
#  ('MELK', 'MELK_G7', 'High silica restriction', 254.6, 0.17),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 delayed ramp-up due to start failure.', 251.62, 0.17),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U2 start up profile on return to service', 250.8, 0.16),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output reduced due to ambient conditions', 245.32, 0.16),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit tripped due to blown fuse on blade pass temperature element', 242.56, 0.16),
#  ('MELK', 'MELK_G7', 'MFT / MTR', 227.0, 0.15),
#  ('MELK', 'MELK_G7', 'Unit unavailable for RTS.', 227.0, 0.15),
#  ('MELK', 'MELK_G7', 'Unit unavailable for dispatch.', 227.0, 0.15),
#  ('AURICON', 'AURICON_PNJ_U1', 'Plant pulsation alarm issue', 220.03, 0.14),
#  ('MELK', 'MELK_G7', 'Retirement pending deregistration.', 220.0, 0.14),
#  ('MELK', 'MELK_G7', 'Unit MFT/MTR.', 215.0, 0.14),
#  ('GW', 'BW1_GREENWATERS_G2', 'Kemerton_GT12 tripped on start\n', 213.2, 0.14),
#  ('GW', 'BW1_GREENWATERS_G2', 'Kemerton_GT12 tripped on start triggering protection which affected Kemerton_GT11\n', 213.2, 0.14),
#  ('MELK', 'MELK_G7', 'Delayed Return To service', 211.11, 0.14),
#  ('MELK', 'MELK_G7', 'Delayed Synchronisation.', 211.0, 0.14),
#  ('MELK', 'MELK_G7', 'RTS Delayed', 211.0, 0.14),
#  ('MELK', 'MELK_G7', 'Unit MTR', 211.0, 0.14),
#  ('MELK', 'MELK_G7', 'Boiler drain line damage', 208.98, 0.14),
#  ('MELK', 'MELK_G7', 'Delayed Unit RTS', 208.98, 0.14),
#  ('MELK', 'MELK_G7', 'Delays in unit return to service post major outage', 208.98, 0.14),
#  ('MELK', 'MELK_G7', 'Low control oil pressure trip', 208.98, 0.14),
#  ('MELK', 'MELK_G7', 'Unit trip due to hydraulic fault. Pro-rata forced outage', 206.0, 0.14),
#  ('MELK', 'MELK_G7', 'Boiler Maintenance', 205.9, 0.14),
#  ('MELK', 'MELK_G7', 'Master Fuel Trip, loss of fuel to feeder', 205.9, 0.14),
#  ('MELK', 'MELK_G7', 'Unit Trip', 205.9, 0.14),
#  ('MELK', 'MELK_G7', 'Unit delay RTS', 205.9, 0.14),
#  ('MELK', 'MELK_G7', 'Hardwire trip fault', 200.0, 0.13),
#  ('MELK', 'MELK_G7', 'Master fuel trip', 196.63, 0.13),
#  ('MELK', 'MELK_G7', 'Load limitation', 193.0, 0.13),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp up', 190.57, 0.13),
#  ('AURICON', 'AURICON_PNJ_U1', 'Battery charger fault discovered', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Battery charger fault discovered.', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Extension of outage #228336 due to unforeseen workscope overrun', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Routine Maintenance Outage extended - Sequence Release issue', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Routine maintenance outage overrun', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'The unit failed to start.\n', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unable to meet dispatch instruction', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unable to meet dispatch instruction\n', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unable to reach dispatch target issued by Random Number Generator.', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit failed to start.', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 not started due to uneconomic short run.', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 start fail due to fuel drain valve limit switch fault', 190.0, 0.12),
#  ('MELK', 'MELK_G7', 'Partial forced outage after unit runback caused by CW Pump trip', 190.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit had problems ramping up to dispatch target', 188.26, 0.12),
#  ('MELK', 'MELK_G7', 'Forced partial outage due to failure of CW pump.', 187.24, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit did not reach target', 184.59, 0.12),
#  ('MELK', 'MELK_G7', 'ID fan bearing failure - output reduced to 160MW', 183.24, 0.12),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to CW pump trip.', 183.24, 0.12),
#  ('MELK', 'MELK_G7', 'Forced outage: Unit trip during turbine valve testing', 180.0, 0.12),
#  ('AURICON', 'AURICON_PNJ_U1', 'delayed synchronization due to failure of fuel drain valve close limit switch', 177.33, 0.12),
#  ('MELK', 'MELK_G7', 'condenser level trip', 175.08, 0.11),
#  ('MELK', 'MELK_G7', 'Main Fuel Trip due to wet coal', 173.82, 0.11),
#  ('MELK', 'MELK_G7', 'Partial forced outage. 3 mill operation', 171.19, 0.11),
#  ('GW', 'BW1_GREENWATERS_G2', 'Forced outage', 170.0, 0.11),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delayed synch due to breaker fault', 167.91, 0.11),
#  ('AURICON', 'AURICON_PNJ_U1', 'Flame out trip during loading for capacity test', 163.96, 0.11),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to CW pump trip', 163.24, 0.11),
#  ('AURICON', 'AURICON_PNJ_U1', 'Operational issues caused unit trip.', 162.07, 0.11),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to delay in RTS', 160.0, 0.11),
#  ('AURICON', 'AURICON_PNJ_U1', 'Wagerup U1 slow to ramp due to plant issues', 159.68, 0.1),
#  ('MELK', 'MELK_G7', 'Over-speed trip fault', 159.13, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U1 delayed return to service after outage', 158.2, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delay in unit ramp-up', 157.88, 0.1),
#  ('MELK', 'MELK_G7', 'Pro rata forced outage due to unit trip', 157.39, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp to dispatch target following unexpected direction to commit from System Management', 156.01, 0.1),
#  ('GW', 'BW1_GREENWATERS_G2', 'Combustion chamber failed to fire.  Protection Shutdown.', 156.0, 0.1),
#  ('GW', 'BW1_GREENWATERS_G2', 'Failed to start', 156.0, 0.1),
#  ('MELK', 'MELK_G7', 'Unable to fire the boiler on coal.', 155.9, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'fuel gas control valve issue', 152.86, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'Issues with ramping up\n', 152.25, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'Fuel valves issue', 151.79, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit did not meet target during ramp-up', 148.29, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'Wind farm tripped', 147.1, 0.1),
#  ('MELK', 'MELK_G7', 'Partial forced outage - Unit load restricted to 270MW.', 146.48, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramp-up', 146.41, 0.1),
#  ('MELK', 'MELK_G7', 'Forced partial outage (pro-rata) due to failure of CW pump.', 145.33, 0.1),
#  ('MELK', 'MELK_G7', '11 KV supply Protection Activated', 145.0, 0.1),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U2 delayed return from Blade Wash Outage due to Steam Leak', 143.0, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit trip during RTS from blade wash outage', 143.0, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit tripped during startup coming from outage due to a HH alarm on IP drum level.', 143.0, 0.09),
#  ('MELK', 'MELK_G7', 'HP Cylinder metal stress', 140.66, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'Late synchronisation due to communications failure between the control room and the unit', 136.43, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'unit slow to ramp up', 136.24, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit in commissioning. Ramping issue.', 135.92, 0.09),
#  ('MELK', 'MELK_G7', 'ID fan bearing failure - output reduced to 160MW (pro-rata)', 134.2, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'Late ramp up.', 133.8, 0.09),
#  ('MELK', 'MELK_G7', 'LP Differential Expansion issue', 133.14, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'WGP U2 shut down early - Email advice from Trading not received', 133.1, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit start-up profile operational requirement', 132.55, 0.09),
#  ('MELK', 'MELK_G7', 'Electrical fault causing turbine trip. Delayed synchronisation. Gate Closure Violation.', 132.5, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up. ', 131.64, 0.09),
#  ('AURICON', 'AURICON_PNJ_U1', 'slow to ramp up', 131.23, 0.09),
#  ('MELK', 'MELK_G7', 'Delay during synchronization', 130.06, 0.09),
#  ('MELK', 'MELK_G7', 'ID fan control limitation', 126.11, 0.08),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit issues ramping up to dispatch target due to safety concern when high rotor temperature alarm got activated', 124.58, 0.08),
#  ('GW', 'BW1_GREENWATERS_G2', 'No crane available Furnace 1 & 2. For further information contact Simcoa Furnace Control on 9780 6670', 123.9, 0.08),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit restart, plant conditions preventing unit following ramp up profile', 122.08, 0.08),
#  ('MELK', 'MELK_G7', 'Load reduction', 121.0, 0.08),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp up', 120.19, 0.08),
#  ('MELK', 'MELK_G7', 'Load Limitation', 120.0, 0.08),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp up, unit returning to service from outage\n', 119.28, 0.08),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage. 3 mill operation', 119.24, 0.08),
#  ('MELK', 'MELK_G7', 'Boiler feed pump failure', 115.9, 0.08),
#  ('MELK', 'MELK_G7', 'Boiler inspection ', 115.0, 0.08),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit tripped while ramping up to full load on return to service.\n', 114.87, 0.08),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up\n', 111.42, 0.07),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Stack emission testing requirement\n', 111.28, 0.07),
#  ('AURICON', 'AURICON_PNJ_U1', 'high LP drum pressure as a result of the failure of the feedback arm from the IP to lp bled steam valve', 110.74, 0.07),
#  ('MELK', 'MELK_G7', 'Under Voltage Relay Trip', 109.5, 0.07),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delayed RTS of the unit from blade wash', 109.36, 0.07),
#  ('AURICON', 'AURICON_PNJ_U1', 'Ambient condition limitation', 108.28, 0.07),
#  ('MELK', 'MELK_G7', 'Partial load restriction', 108.0, 0.07),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit did not reach target due to unit trip.', 107.77, 0.07),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage due to CW pump trip.', 103.84, 0.07),
#  ('GW', 'BW1_GREENWATERS_G2', 'Unit 11 trip on gas detector failure', 103.0, 0.07),
#  ('MELK', 'MELK_G7', 'Turbine limitation', 102.46, 0.07),
#  ('MELK', 'MELK_G7', 'Mill trips took unit offline', 102.22, 0.07),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Contractor tuning requireme', 100.33, 0.07),
#  ('MELK', 'MELK_G7', 'Feedwater restriction.', 100.0, 0.07),
#  ('MELK', 'MELK_G7', 'Unavailability of plant', 100.0, 0.07),
#  ('MELK', 'MELK_G7', 'Loss of vacuum trip', 99.77, 0.07),
#  ('MELK', 'MELK_G7', 'Mill trip', 98.89, 0.06),
#  ('GW', 'BW1_GREENWATERS_G2', 'Kemerton_GT12 tripped on start triggering protection which affected Kemerton_GT11', 98.8, 0.06),
#  ('GW', 'BW1_GREENWATERS_G2', 'Operational issue on start up', 98.8, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit did not reach target.', 98.26, 0.06),
#  ('MELK', 'MELK_G7', 'Pro-rata Unit run back due to thermocouple fault.', 97.9, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Cold ambient temp, no high fogging permissives', 95.51, 0.06),
#  ('MELK', 'MELK_G7', 'Condenser and cooling tower performance', 95.0, 0.06),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to delay in RTS (pro-rata)', 90.66, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit shut down for outage.', 89.14, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Transformer 1 and 2 offline for HV maintenance', 89.1, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp up from outage', 88.59, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Derating due to Ambient condition', 88.26, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Transformer 1 and Collector groups 1 to 3 offline for HV maintenance', 88.2, 0.06),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 unplanned outage', 88.2, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramping up following RTS delay due to unit trip', 87.8, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delay in unit ramp up', 87.53, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'WWF tripped as runback scheme was invoked due to MBA - TS 81 line tripped. MBA TS 81 line tripped due to storms and lightning strikes in the North Country region. Information based on Dispatch Advisory 16400 and 16401 from Western Power.', 87.45, 0.06),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp from previous dispatch due to power augmentation issues.', 85.95, 0.06),
#  ('MELK', 'MELK_G7', 'Unit trip', 85.9, 0.06),
#  ('GW', 'BW1_GREENWATERS_G2', 'Intertrip from Western Power caused ME breaker 801.1 to open.  Intertrip as a result of a lightning storm in the area.  To be converted to a Consequential Outage.', 82.0, 0.05),
#  ('GW', 'BW1_GREENWATERS_G2', 'forced outage due to western power ENAR309085', 82.0, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp down before outage.', 81.82, 0.05),
#  ('MELK', 'MELK_G7', 'Turbine LH ESV opening fault', 81.0, 0.05),
#  ('MELK', 'MELK_G7', 'Full forced outage for RAH repairs (pro-rata)', 80.0, 0.05),
#  ('MELK', 'MELK_G7', 'ID fan capacity', 80.0, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', "Unit's output was constrained due to ventilation fan issues.", 79.25, 0.05),
#  ('MELK', 'MELK_G7', 'FD fan control limitation', 78.98, 0.05),
#  ('MELK', 'MELK_G7', 'Low furnace pressure due to loss of fuel supply', 78.85, 0.05),
#  ('MELK', 'MELK_G7', 'Loss of temperature in the boiler', 77.87, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp from previous setpoint', 77.59, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output from wind farm limited.', 74.85, 0.05),
#  ('MELK', 'MELK_G7', 'ID fan bearing failure - Pro-rata load reduction to 160MW', 74.8, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', 'Generator transformer issue and unit protection.', 74.12, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramping up following delayed RTS due to unit trip', 74.11, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation after unit trip', 72.27, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp up\n', 71.21, 0.05),
#  ('MELK', 'MELK_G7', 'PA fan capacity', 69.0, 0.05),
#  ('MELK', 'MELK_G7', 'Issue with feeder', 68.99, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', 'High fogging system, PLC card failure', 68.71, 0.05),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Stack emmission testing requirement and load swing\n', 67.72, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit unable to reach target due to ambient conditions.', 67.67, 0.04),
#  ('MELK', 'MELK_G7', 'Wet Coal Issues', 65.43, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unable to meet dispatch instruction.', 65.05, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Under generation - ambient conditions', 63.67, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp', 63.53, 0.04),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to mill issue', 63.24, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Transformer 1 offline for HV maintenance', 62.2, 0.04),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage after unit runback caused by CW Pump trip', 60.17, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output reduced due to ambient conditions.', 60.05, 0.04),
#  ('MELK', 'MELK_G7', 'Cooling Tower Fans tripped.', 60.0, 0.04),
#  ('GW', 'BW1_GREENWATERS_G2', 'Ladle car derailment', 58.0, 0.04),
#  ('MELK', 'MELK_G7', 'Pro-rata forced outage after unit trip', 57.2, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Contractor tuning requirement.', 56.64, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramp up following delayed RTS due to unit trip', 56.43, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Evaporative cooling inoperative due to demin water plant defect', 56.0, 0.04),
#  ('MELK', 'MELK_G7', 'Brush Gear repairs', 55.0, 0.04),
#  ('MELK', 'MELK_G7', 'Electrical fault resulting in turbine trip', 55.0, 0.04),
#  ('MELK', 'MELK_G7', 'Governor Control Fault', 55.0, 0.04),
#  ('MELK', 'MELK_G7', 'M7 CW temperature high', 55.0, 0.04),
#  ('MELK', 'MELK_G7', 'Over speed bolt test unsuccessful  ', 55.0, 0.04),
#  ('MELK', 'MELK_G7', 'Steam to metal temperature mismatch across turbine', 55.0, 0.04),
#  ('MELK', 'MELK_G7', 'Synchronisation delay due to temperature related issues', 55.0, 0.04),
#  ('MELK', 'MELK_G7', 'Technical support required to synchronise due to bearing vibrations', 55.0, 0.04),
#  ('MELK', 'MELK_G7', 'Partial forced outage (pro-rata) due to CW pump trip', 54.4, 0.04),
#  ('MELK', 'MELK_G7', 'Partial forced outage (pro-rata) due to mill issue', 53.5, 0.04),
#  ('AURICON', 'AURICON_PNJ_U1', 'Delayed ramp-up to target', 53.18, 0.03),
#  ('MELK', 'MELK_G7', 'Runback due to loss of fuel supply', 51.98, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Oil leak on Ph1', 49.0, 0.03),
#  ('MELK', 'MELK_G7', 'Delay to unit synchronization', 48.23, 0.03),
#  ('MELK', 'MELK_G7', 'Turbine governor valve fault', 47.11, 0.03),
#  ('MELK', 'MELK_G7', 'Centre CW pump outage', 47.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Unit trip on start', 46.8, 0.03),
#  ('MELK', 'MELK_G7', 'Partial forced outage (pro-rata) due to boiler feed pump trip', 46.11, 0.03),
#  ('MELK', 'MELK_G7', 'Pro-rata full forced outage due to unit trip.', 45.78, 0.03),
#  ('MELK', 'MELK_G7', 'Erratic governor control system  ', 45.14, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output limited due to ambient conditions', 45.13, 0.03),
#  ('MELK', 'MELK_G7', 'M7 Cooling Tower Fans tripped.', 45.0, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Three collector groups tripped offline due to a suspected cable fault', 44.6, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit derating', 44.59, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Wind farm output limited', 44.1, 0.03),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to ESP pass out of service', 43.24, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Maximum output limited due to ambient conditions', 43.12, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation on ramp up from outage', 43.0, 0.03),
#  ('MELK', 'MELK_G7', 'FW limitation', 43.0, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit output below dispatch target due to ambient conditions.', 42.51, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Local signal error', 42.1, 0.03),
#  ('MELK', 'MELK_G7', 'Turbine temperature and vibration issues during ramp up', 42.06, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Baghouse Fans electrical trip', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'CV009 issues', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Chain curtain drive fault, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Chain curtain drive fault, Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 - Server communication fault.  For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Hydraulic hose failure', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Mechanical failure experienced on one of the main baghouse fans. Furnace 1&2 affected. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'No batching, Furnace 1 and 2. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Remove isolation plates on fan 12. Plant affected, Furnace 1 and 2. \n\nFor further information contact Simcoa Furnace Control on 9780 6670.', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Water lines. For further information contact Simcoa Furnace Control on 9780 6670', 42.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Western Power Trip', 42.0, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Limited maximum output', 41.51, 0.03),
#  ('MELK', 'MELK_G7', 'Unit ramped up slower than scheduled due to temperature differentials', 41.23, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Under shoot dispatch target when ramping down', 41.01, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', ' Gt2 Fire panel fault', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Fire Protection Fault', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 Fire protection instrument fault', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 Main Step Transformer temperature transducer lost signal making the TX unavailable.', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 Starter diesel failure to start.', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 fire protection panel instrument fault ', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 logic issue', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 went unavailable due to Fire System fault again, John from AEMO rang me at 1402 on Saturday 03 December.', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT1 went unavailable due to Fire System fault.', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT2 Caterpillar starter had issues, required a rebuild.', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT2 fire Panel fault', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT2 unable to synchronize to grid ', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'GT2 unavailable due to fire protection fault', 41.0, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'fire protection fault', 41.0, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp from previous dispatch', 40.15, 0.03),
#  ('MELK', 'MELK_G7', 'Issue with Variable Speed Drive on Pulveriser A/B', 40.1, 0.03),
#  ('MELK', 'MELK_G7', 'M8 CW temperature high and poor vacuum', 40.0, 0.03),
#  ('MELK', 'MELK_G7', 'RAH Blockage limiting load', 39.0, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp down\n', 38.96, 0.03),
#  ('MELK', 'MELK_G7', 'Partial pro-rata forced outage due to ESP pass out of service', 38.91, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2 outage', 38.5, 0.03),
#  ('GW', 'BW1_GREENWATERS_G2', 'MCC Isolating Switch Fault', 38.5, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'Load swing testing', 38.11, 0.03),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ1 max output reduced due to ambient conditions', 37.92, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Rotor temperature issue.', 37.6, 0.02),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 tap hole breakout', 37.0, 0.02),
#  ('MELK', 'MELK_G7', 'Reduced load ', 37.0, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'due to ambient condition', 36.35, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp up from start up.', 36.32, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'SCADA issue causing outage of 14 turbines', 36.1, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp from previous dispatch.', 35.04, 0.02),
#  ('GW', 'BW1_GREENWATERS_G2', 'Curtailment shutdown', 35.0, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Reserve capacity testing', 34.06, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Evaporative cooling ineffective due to ambient temperature.', 33.85, 0.02),
#  ('MELK', 'MELK_G7', 'RAH high load', 31.11, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Transformer 2 offline for HV maintenance', 31.1, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'CG1 and CG4 outage.', 30.0, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'CG1 outage.', 30.0, 0.02),
#  ('MELK', 'MELK_G7', 'Boiler combustion plant capacity', 30.0, 0.02),
#  ('MELK', 'MELK_G7', 'Issue with oil guns', 29.44, 0.02),
#  ('GW', 'BW1_GREENWATERS_G2', 'Spring pack leak', 28.0, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Output limited due to high ambient temperature', 27.45, 0.02),
#  ('MELK', 'MELK_G7', 'Drum level indication and control fault', 27.0, 0.02),
#  ('MELK', 'MELK_G7', 'Forced partial outage due to mill trip', 27.0, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Communications outage', 26.1, 0.02),
#  ('GW', 'BW1_GREENWATERS_G2', 'Kemerton_GT12 tripped on start', 26.0, 0.02),
#  ('MELK', 'MELK_G7', 'Boiler issue', 25.6, 0.02),
#  ('MELK', 'MELK_G7', 'Pro rata partial forced outage after unit runback caused by CW Pump trip', 25.33, 0.02),
#  ('MELK', 'MELK_G7', 'Issue with the feeder', 25.02, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'delayed ramp-up due to high fogging, evaporative cooler and water injection system', 24.48, 0.02),
#  ('MELK', 'MELK_G7', 'Verbal DI to increase load. Unit ramped up slower than submitted ramp rate due to temperature differentials', 24.18, 0.02),
#  ('GW', 'BW1_GREENWATERS_G2', 'Box overflowed, burnt tracks', 24.0, 0.02),
#  ('GW', 'BW1_GREENWATERS_G2', 'Hydraulic oil leak Phase 1 Contact Pad Lines', 23.8, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Deviation from commissioning test plan. Stack emmission testing requirement\n', 23.71, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp', 23.62, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit had limited output.', 22.9, 0.02),
#  ('AURICON', 'AURICON_PNJ_U1', 'unit slow to ramp up.', 22.22, 0.01),
#  ('MELK', 'MELK_G7', 'Load restriction', 22.0, 0.01),
#  ('MELK', 'MELK_G7', 'Partial pro-rata forced outage due to precip fault', 21.67, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ2 max output reduced due to ambient conditions.', 21.16, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', '11MVAr protection (breaker change out), Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Blown fume duct to ph1 electrode cooling', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Blown hydraulic hose, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Broken electrode. Kibble changeout. Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Casting crane failure. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Chain curtain drive fault', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Emergency generator caused hydraulic fault and demin water plant trip', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Flow meter problem on Line 35', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Fu1 Chain curtain fallen off.  For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Fume duct issue', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 Outage', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 Phase 2 oil leak repair', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1 water leak ? Transformer line 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2 OOS', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2 broken electrode phase 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2. Dango tripped with stoking arm in the furnace. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace off due to water leak on contact pad line - Furnace 2', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace repairs', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace1, Taphole repack.  For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Hydraulic leak', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Hydraulic oil leak Phase 2 contact clamp', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Ladle car derailed, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Launder failure and rebuild. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'MCC fault', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'No water flow line 37 contact pad phase 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Oil Leak on Phase 2 .  For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Oil leak', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Oil leak on ph1 furnace 1.  For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Repair fuel oil lines', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Repair major water leak from pressure ring', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Repair to floor plate stoking floor, Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Repairs to chain curtain', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Replace fume duct onto feeder 203, Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Taphole blow and repack, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Taphole maintenance', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Taphole repair, Furnace1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Tapping fan MCC fault', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Water leak Ph2 Fu1. For further information contact Simcoa Furnace Control on 9780 6670', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Water leak on hood', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Water leak on phase 1 pressure ring. For further information contact Simcoa Furnace Control on 9780 6670 ', 21.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'high current, incoming breaker faul', 21.0, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'delayed ramping due to ticking water valve that delayed the start of the power augmentation system', 20.97, 0.01),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage - Unit load restricted to 270MW from 18:52.', 19.53, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U1 failed to meet dispatch target due to ramping.', 19.21, 0.01),
#  ('MELK', 'MELK_G7', 'Pro-rata Partial forced outage. 3 mill operation', 18.81, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp rate due to power augmentation limitations', 18.71, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'slow to ramp up ', 18.68, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp up due to Blade Path Temperature control limit', 18.52, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 2 - Taphole blow and repack ', 18.5, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Evaporative cooler pump issues\n', 18.44, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'max output reduced due to ambient conditions.', 18.4, 0.01),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to PF leak on mill. Unit reduced to three mill operation.', 18.24, 0.01),
#  ('MELK', 'MELK_G7', 'Partial forced outage due to mill failure. Reduced to three mill operation.', 18.24, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Due to issues with the high fogging system', 17.41, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Furnace 1, Large Flame and repack. For further information contact Simcoa Furnace Control on 9780 6670', 17.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Start up curve, Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 17.0, 0.01),
#  ('MELK', 'MELK_G7', 'loss of a cooling tower fan', 16.93, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Derailed box cart', 16.0, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Outage of collector group 3 due to suspected cable fault trip', 15.1, 0.01),
#  ('MELK', 'MELK_G7', 'operator was delayed in initiating ramp up', 15.08, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'CG1 outage', 15.0, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'CG4 outage.', 15.0, 0.01),
#  ('MELK', 'MELK_G7', 'High differential pressure in the baghouse', 15.0, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Collector group 1 de-energised to allow turbine repairs', 14.85, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Collector group 5 outage caused by failure of RMU on turbine 44.', 14.85, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Collector group outage', 14.85, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Collector group unavailable due to a cable fault', 14.85, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Investigate and conduct reports on a turbine\n', 14.85, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'turbine fault', 14.85, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Inlet temperature issues.', 14.07, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', '11MVar cap bank fault', 14.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', '11MVar cap bank fault ', 14.0, 0.01),
#  ('MELK', 'MELK_G7', 'Boiler capacity', 14.0, 0.01),
#  ('MELK', 'MELK_G7', 'Additional DI instructed within interval when unit was already ramping. Unable to comply.', 13.9, 0.01),
#  ('MELK', 'MELK_G7', 'issue with the baghouse', 13.78, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp for capacity testing', 13.77, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit unable to reach tartget due to ambient conditions', 13.65, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit slow to ramp to full capacity during capacity testing', 13.61, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit ramping limited on return to service', 13.47, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp up.', 13.24, 0.01),
#  ('MELK', 'MELK_G7', 'Mill A and Mill C starting faults', 11.9, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Forced Outage', 11.35, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Launder failure Furnace 2. For further information contact Simcoa Furnace Control on 9780 6670', 11.3, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Shutdown for baghouse fans blanks.  For further information contact Simcoa Furnace Control on 9780 6670', 11.0, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Startup after shut for oil leak', 11.0, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'PNJ U2 max output reduced due to ambient conditions.', 10.3, 0.01),
#  ('GW', 'BW1_GREENWATERS_G2', 'Delay energising', 10.0, 0.01),
#  ('MELK', 'MELK_G7', 'Baghouse Issues', 10.0, 0.01),
#  ('MELK', 'MELK_G7', 'Loss of a cooling tower fan', 10.0, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow ramp up.', 9.2, 0.01),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage due to mill failure. Reduced to three mill operation for 15 minutes.', 9.12, 0.01),
#  ('MELK', 'MELK_G7', 'Turbine vibrations', 8.98, 0.01),
#  ('AURICON', 'AURICON_PNJ_U1', 'Unit output below dispatch target due to ambient', 8.87, 0.01),
#  ('MELK', 'MELK_G7', 'West Boiler feed pump Outage', 8.0, 0.01),
#  ('MELK', 'MELK_G7', 'operator was delayed in initiating ramp up ', 7.9, 0.01),
#  ('MELK', 'MELK_G7', 'Loss of a mill', 7.48, 0.0),
#  ('AURICON', 'AURICON_PNJ_U1', 'unit derating', 7.06, 0.0),
#  ('MELK', 'MELK_G7', 'Boiler feed pump, condenser and cooling tower performance', 7.0, 0.0),
#  ('MELK', 'MELK_G7', 'Coal feeder swap', 6.82, 0.0),
#  ('MELK', 'MELK_G7', 'Coal issue', 6.74, 0.0),
#  ('MELK', 'MELK_G7', 'Mill Issue', 6.12, 0.0),
#  ('AURICON', 'AURICON_PNJ_U1', 'Slow to ramp. Output limited due to ambient conditions.', 6.02, 0.0),
#  ('GW', 'BW1_GREENWATERS_G2', 'Fan 13 off line due to maintenance work. For further information contact Simcoa Furnace Control on 9780 6670', 6.0, 0.0),
#  ('AURICON', 'AURICON_PNJ_U1', 'Limited output due to ambient conditions', 5.82, 0.0),
#  ('GW', 'BW1_GREENWATERS_G2', 'ladle car derailment', 5.0, 0.0),
#  ('MELK', 'MELK_G7', 'Baghouse issue resulting in restricted load', 5.0, 0.0),
#  ('MELK', 'MELK_G7', 'Baghouse issue resulting in restricted load\n', 5.0, 0.0),
#  ('MELK', 'MELK_G7', 'Rotary Air Heater seals', 4.72, 0.0),
#  ('MELK', 'MELK_G7', 'Pro-rata partial forced outage due to PF leak on mill. Unit reduced to three mill operation.', 4.26, 0.0),
#  ('MELK', 'MELK_G7', 'Boiler feedpump capacity', 4.0, 0.0),
#  ('MELK', 'MELK_G7', 'North Boiler feed pump oil leak', 4.0, 0.0),
#  ('MELK', 'MELK_G7', 'Turbine control limitations', 4.0, 0.0),
#  ('MELK', 'MELK_G7', 'Turbine limitations', 4.0, 0.0),
#  ('GW', 'BW1_GREENWATERS_G2', 'No crane available Furnace 1. For further information contact Simcoa Furnace Control on 9780 6670', 2.1, 0.0),
#  ('AURICON', 'AURICON_PNJ_U1', 'Reduced generation capability', 1.0, 0.0),
#  ('GW', 'BW1_GREENWATERS_G2', 'Maintenance Shutdown - Total power used 0MW as Furnace 1 is still shutdown', 0.0, 0.0)]
